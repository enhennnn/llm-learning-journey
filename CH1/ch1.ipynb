# %% [markdown]
# > **License & Attribution**
# > This notebook is a derivative of [LLMs-from-scratch](https://github.com/rasbt/LLMs-from-scratch)
# > by Sebastian Raschka, licensed under the Apache License 2.0.
# > Modifications made by [enhennnn].
# >
# > SPDX-License-Identifier: Apache-2.0
# > For the full license text, see the [LICENSE](LICENSE) file in this repository

# %% [markdown]
# &nbsp;
# ## 1.简单分词法——按单词分token

# %% [markdown]
# - 在线可视化分词网页
# <a href="https://tiktokenizer.vercel.app/">https://tiktokenizer.vercel.app</a>

# %%
import os
import urllib.request
import re

# %%
#加载text文件
with open("the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()
print(raw_text)
len(raw_text)
# Out:
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no great surprise to me to hear that, in the height of his glory, he had dropped his painting, married a rich widow, and established himself in a villa on the Riviera. (Though I rather thought it would have been Rome or Florence.)
#
# "The height of his glory"--that was what the women called it. I can hear Mrs. Gideon Thwing--his last Chicago sitter--deploring his unaccountable abdication. "Of course it's going to send the value of my picture 'way up; but I don't think of that, Mr. Rickham--the loss to Arrt is all I think of." The word, on Mrs. Thwing's lips, multiplied its _rs_ as though they were reflected in an endless vista of mirrors. And it was not only the Mrs. Thwings who mourned. Had not the exquisite Hermia Croft, at the last Grafton Gallery show, stopped me before Gisburn's "Moon-dancers" to say, with tears in her eyes: "We shall not look upon its like again"?
#
# ...

# %%
#分词，使用正则表达式将文本分割成单词和标点符号
result = re.split(r'([,.:;?_!"()\']|--|\s)', raw_text)
print(result)
# Out:
# ['I', ' ', 'HAD', ' ', 'always', ' ', 'thought', ' ', 'Jack', ' ', 'Gisburn', ' ', 'rather', ' ', 'a', ' ', 'cheap', ' ', 'genius', '--', 'though', ' ', 'a', ' ', 'good', ' ', 'fellow', ' ', 'enough', '--', 'so', ' ', 'it', ' ', 'was', ' ', 'no', ' ', 'great', ' ', 'surprise', ' ', 'to', ' ', 'me', ' ', 'to', ' ', 'hear', ' ', 'that', ',', '', ' ', 'in', ' ', 'the', ' ', 'height', ' ', 'of', ' ', 'his', ' ', 'glory', ',', '', ' ', 'he', ' ', 'had', ' ', 'dropped', ' ', 'his', ' ', 'painting', ',', '', ' ', 'married', ' ', 'a', ' ', 'rich', ' ', 'widow', ',', '', ' ', 'and', ' ', 'established', ' ', 'himself', ' ', 'in', ' ', 'a', ' ', 'villa', ' ', 'on', ' ', 'the', ' ', 'Riviera', '.', '', ' ', '', '(', 'Though', ' ', 'I', ' ', 'rather', ' ', 'thought', ' ', 'it', ' ', 'would', ' ', 'have', ' ', 'been', ' ', 'Rome', ' ', 'or', ' ', 'Florence', '.', '', ')', '', '\n', '', '\n', '', '"', 'The', ' ', 'height', ' ', 'of', ' ', 'his', ' ', 'glory', '"', '', '--', 'that', ' ', 'was', ' ',
# ...

# %%
#去掉空格和换行符，以及分词结果中的空字符串
result = [item for item in result if item.strip()]
print(result)
preprocessed = result
len(preprocessed)
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory', ',', 'he', 'had', 'dropped', 'his', 'painting', ',', 'married', 'a', 'rich', 'widow', ',', 'and', 'established', 'himself', 'in', 'a', 'villa', 'on', 'the', 'Riviera', '.', '(', 'Though', 'I', 'rather', 'thought', 'it', 'would', 'have', 'been', 'Rome', 'or', 'Florence', '.', ')', '"', 'The', 'height', 'of', 'his', 'glory', '"', '--', 'that', 'was', 'what', 'the', 'women', 'called', 'it', '.', 'I', 'can', 'hear', 'Mrs', '.', 'Gideon', 'Thwing', '--', 'his', 'last', 'Chicago', 'sitter', '--', 'deploring', 'his', 'unaccountable', 'abdication', '.', '"', 'Of', 'course', 'it', "'", 's', 'going', 'to', 'send', 'the', 'value', 'of', 'my', 'picture', "'", 'way', 'up', ';', 'but', 'I', 'don', "'", 't', 'think', 'of', 'that', 
# ...

# %% [markdown]
# &nbsp;
# ## 2.创建token词表，将token和token ID对应

# %%
#先构建token表：all_tokens，再构建词表：vocab
all_tokens = sorted(set(preprocessed))
print(all_tokens)
vocab_size = len(all_tokens)
print(vocab_size)
vocab = {token:integer for integer, token in enumerate(all_tokens)}
print(vocab)
# Out:
# ['!', '"', "'", '(', ')', ',', '--', '.', ':', ';', '?', 'A', 'Ah', 'Among', 'And', 'Are', 'Arrt', 'As', 'At', 'Be', 'Begin', 'Burlington', 'But', 'By', 'Carlo', 'Chicago', 'Claude', 'Come', 'Croft', 'Destroyed', 'Devonshire', 'Don', 'Dubarry', 'Emperors', 'Florence', 'For', 'Gallery', 'Gideon', 'Gisburn', 'Gisburns', 'Grafton', 'Greek', 'Grindle', 'Grindles', 'HAD', 'Had', 'Hang', 'Has', 'He', 'Her', 'Hermia', 'His', 'How', 'I', 'If', 'In', 'It', 'Jack', 'Jove', 'Just', 'Lord', 'Made', 'Miss', 'Money', 'Monte', 'Moon-dancers', 'Mr', 'Mrs', 'My', 'Never', 'No', 'Now', 'Nutley', 'Of', 'Oh', 'On', 'Once', 'Only', 'Or', 'Perhaps', 'Poor', 'Professional', 'Renaissance', 'Rickham', 'Riviera', 'Rome', 'Russian', 'Sevres', 'She', 'Stroud', 'Strouds', 'Suddenly', 'That', 'The', 'Then', 'There', 'They', 'This', 'Those', 'Though', 'Thwing', 'Thwings', 'To', 'Usually', 'Venetian', 'Victor', 'Was', 'We', 'Well', 'What', 'When', 'Why', 'Yes', 'You', '_', 'a', 'abdication', 'able', 'about', 'above
# ...

# %%
#构建tokenizer，实现encode和decode方法
class SimpleTokenizerV1:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = {integer:token for token,integer in vocab.items()}
        
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)     
        preprocessed = [item.strip() for item in preprocessed if item.strip()]
        
        ids = [self.str_to_int[token] for token in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[integer] for integer in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.?!"()\'])', r'\1', text)
        return text

# %%
#测试tokenizer，看看encode和decode的结果
tokenizer = SimpleTokenizerV1(vocab)
ids = tokenizer.encode(raw_text)
print(ids)
decoded_text = tokenizer.decode(ids)
print(decoded_text)
# Out:
# [53, 44, 149, 1003, 57, 38, 818, 115, 256, 486, 6, 1002, 115, 500, 435, 392, 6, 908, 585, 1077, 709, 508, 961, 1016, 663, 1016, 535, 987, 5, 568, 988, 538, 722, 549, 496, 5, 533, 514, 370, 549, 748, 5, 661, 115, 841, 1102, 5, 157, 397, 547, 568, 115, 1066, 727, 988, 84, 7, 3, 99, 53, 818, 1003, 585, 1120, 530, 208, 85, 734, 34, 7, 4, 1, 93, 538, 722, 549, 496, 1, 6, 987, 1077, 1089, 988, 1112, 242, 585, 7, 53, 244, 535, 67, 7, 37, 100, 6, 549, 602, 25, 897, 6, 326, 549, 1042, 116, 7, 1, 73, 297, 585, 2, 850, 498, 1016, 866, 988, 1059, 722, 697, 769, 2, 1083, 1051, 9, 239, 53, 359, 2, 970, 998, 722, 987, 5, 66, 7, 83, 6, 988, 646, 1016, 16, 584, 145, 53, 998, 722, 7, 1, 93, 1116, 5, 727, 67, 7, 100, 2, 850, 633, 5, 693, 586, 114, 847, 114, 177, 1002, 994, 1088, 827, 568, 156, 389, 1069, 722, 677, 7, 14, 585, 1077, 711, 731, 988, 67, 7, 101, 1097, 688, 7, 45, 711, 988, 410, 50, 28, 5, 180, 988, 602, 40, 36, 882, 5, 929, 663, 209, 38, 2, 850, 1, 65, 1, 1016, 856, 5, 1108, 976, 568, 539,
# ...

# %% [markdown]
# &nbsp;
# ## 3.增加特殊的token

# %%
all_tokens = sorted(list(set(preprocessed)))
#先添加到token表中
all_tokens.extend(["<|endoftext|>","<|unk|>"])
#再构建词表
vocab = {token:integer for integer, token in enumerate(all_tokens)}

vocab_size = len(all_tokens)
print(vocab_size)
print(vocab)
# Out:
# 1132
# ...

# %%
#因为增加了特殊token，所以需要重新构建tokenizer
class SimpleTokenizerV2:
    def __init__(self, vocab):
        self.str_to_int = vocab
        self.int_to_str = { i:s for s,i in vocab.items()}
    
    def encode(self, text):
        preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
        preprocessed = [item.strip() for item in preprocessed if item.strip()]
        
        ##########这里发生了改变：如果分词结果中的token不在词表中，就用<|unk|>代替
        preprocessed = [
            item 
            if item in self.str_to_int else "<|unk|>" 
            for item in preprocessed
        ]

        ids = [self.str_to_int[s] for s in preprocessed]
        return ids
        
    def decode(self, ids):
        text = " ".join([self.int_to_str[i] for i in ids])
        # Replace spaces before the specified punctuations
        text = re.sub(r'\s+([,.:;?!"()\'])', r'\1', text)
        return text

# %%
#测试修改后的tokenizer，看看特殊token的效果
tokenizer = SimpleTokenizerV2(vocab)

text = "Hello, world! This is a test of the tokenizer."
ids = tokenizer.encode(text)
print(ids)
decoded_text = tokenizer.decode(ids)
print(decoded_text)
# Out:
# [1131, 5, 1131, 0, 97, 584, 115, 1131, 722, 988, 1131, 7]
# <|unk|>, <|unk|>! This is a <|unk|> of the <|unk|>.

# %% [markdown]
# &nbsp;
# ## 4.Byte pair encoding(BPE)

# %% [markdown]
# - 在这里我们使用的gpt2的tokenizer源码: [https://github.com/openai/gpt-2/blob/master/src/encoder.py](https://github.com/openai/gpt-2/blob/master/src/encoder.py)

# %%
#在这里我们使用tiktoken库实现BPE
import tiktoken
tiktoken.__version__
# Out:
# '0.13.0'

# %%
#使用的是gpt2的tokenizer
#第一次运行需要联网，会自动下载gpt2的tokenizer数据文件，之后就会缓存到本地
tokenizer = tiktoken.get_encoding("gpt2")

text = "Hello, world! This is a test of the tokenizer."
ids = tokenizer.encode(text)
print(ids)
decoded_text = tokenizer.decode(ids)
print(decoded_text)
# Out:
# [15496, 11, 995, 0, 770, 318, 257, 1332, 286, 262, 11241, 7509, 13]
# Hello, world! This is a test of the tokenizer.

# %%
text = "Hello, world! <|endoftext|> This is a test of the tokenizer."

#ids = tokenizer.encode(text)   #这一行会报错，因为文本中包含了tokenizer不认识的特殊token
ids = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(ids)
decoded_text = tokenizer.decode(ids)
print(decoded_text)
# Out:
# [15496, 11, 995, 0, 220, 50256, 770, 318, 257, 1332, 286, 262, 11241, 7509, 13]
# Hello, world! <|endoftext|> This is a test of the tokenizer.

# %% [markdown]
# &nbsp;
# ## 5.使用滑动窗口对数据采样
